# %% [markdown]
# # Risk Analyst: GPU Accelerated Financial Risk Analytics Engine
#
# This notebook automatically orchestrates the compilation, execution, and visualization of the C++/CUDA benchmarking suite.

# %%
# !git clone https://github.com/KushagraB424/RiskAnalyst.git
# %cd RiskAnalyst

# %%
# !nvidia-smi

# %%
# %%bash
# echo "Checking and installing dependencies..."
# apt-get update -qq
# apt-get install -y -qq build-essential cmake libgtest-dev libomp-dev
#
# echo "\n--- Dependency Versions ---"
# nvcc --version | grep "release"
# cmake --version | head -n 1
# g++ --version | head -n 1

# %%
# !mkdir -p build
# !cd build && cmake .. && make -j4

# %%
# !./build/RiskAnalyst

# %%
# !pip install pandas matplotlib
# !cd visualization && python generate_plots.py

# %%
from IPython.display import display, Markdown, Image
import os

results_dir = 'results'
md_path = os.path.join(results_dir, 'benchmark_summary.md')

if os.path.exists(md_path):
    with open(md_path, 'r') as f:
        md_content = f.read()
    # Replace relative paths with explicit display for Jupyter
    display(Markdown(md_content))
else:
    print('Benchmark report not found.')
